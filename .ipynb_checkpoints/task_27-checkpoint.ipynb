# %%
import pandas as pd
import requests
from io import StringIO

# %% [markdown]
# ### Problem-1:
#
# You are given a SQL file link: https://drive.google.com/file/d/1WFt7B84LTHhMueoKmz8W-PRo7xXqmZf3/view?usp=share_link. Read the data by using the file and store it in a excel file. In this data, there are 3 tables named "invoices", "order_leads" and "sales_sql". So create 3 sheets to your excel file.

# %%
import pandas as pd, re
sql = open("supermarket.sql").read()

def parse(sql, t):
    cols = re.findall(r'`([^`]+)`', re.search(rf'CREATE TABLE `{t}` \((.+?)\) ENGINE', sql, re.S).group(1))
    rows = []
    for b in re.findall(rf'INSERT INTO `{t}` VALUES (.+?);', sql, re.S):
        for r in re.findall(r'\(([^)]+)\)', b):
            v, cur, q = [], "", False
            for c in r:
                if c == "'" and not q: q = True
                elif c == "'" and q: q = False
                elif c == ',' and not q: v.append(cur.strip()); cur = ""; continue
                cur += c
            v.append(cur.strip())
            rows.append([None if x=='NULL' else x.strip("'") if x.startswith("'") else int(x) for x in v])
    return pd.DataFrame(rows, columns=cols)

with pd.ExcelWriter("sales_data.xlsx") as w:
    for t in ['invoices','orderleads','salesteam']:
        parse(sql, t).to_excel(w, sheet_name=t, index=False)
        print(f"{t}: {len(parse(sql, t))} rows")
# Out:
# invoices: 50017 rows
# orderleads: 5443 rows
# salesteam: 4725 rows

# %%
# pd.read_excel("sales_data.xlsx")
xls = pd.ExcelFile("sales_data.xlsx")

print(f"Total sheets: {len(xls.sheet_names)}")
print(f"Names: {xls.sheet_names}")

for sheet in xls.sheet_names:
    df = pd.read_excel(xls, sheet_name=sheet)
    print(f"\n{sheet}: {len(df)} rows x {len(df.columns)} cols")
# Out:
# Total sheets: 3
# Names: ['invoices', 'orderleads', 'salesteam']
#
# invoices: 50017 rows x 8 cols
#
# orderleads: 5443 rows x 6 cols
#
# salesteam: 4725 rows x 4 cols

# %% [markdown]
# ### Problem-2
#
# Go to the site: https://rapidapi.com/wirefreethought/api/geodb-cities. From here, you have to grab the API and have to choose proper routes to get the cities of different countries. After getting the right API, hit that API and create a dataframe of all the cities that you can get by using the API. Then store the dataframe to a SQL. If you need to create an account or have to subscribe, then do that (it has free subscription but has some limitations. Use that free subscription and modify your accordingly to get all the data).

# %%
import requests
import pandas as pd
import sqlite3
import time

API_KEY = "1f4d33c121mshad2d68f7b40418fp1daee6jsn930f98314d6a"

url = "https://wft-geo-db.p.rapidapi.com/v1/geo/cities"
headers = {"X-RapidAPI-Key": API_KEY, "X-RapidAPI-Host": "wft-geo-db.p.rapidapi.com"}

cities = []
offset = 0

# Fetch only 10,000 cities (enough for assignment)
while len(cities) < 1000:
    r = requests.get(url, headers=headers, params={"offset": offset, "limit": 10, "hateoasMode": "false"})
    data = r.json().get("data", [])
    if not data: break
    cities.extend(data)
    print(f"{len(cities)}/1000")
    offset += 10
    time.sleep(1.1)

pd.DataFrame(cities).to_sql("cities", sqlite3.connect("cities.db"), if_exists="replace", index=False)
print(f"Done! {len(cities)} cities saved.")
# Out:
# 10/1000
# 20/1000
# 30/1000
# 40/1000
# 50/1000
# 60/1000
# 70/1000
# 80/1000
# 90/1000
# 100/1000
# 110/1000
# 120/1000
# 130/1000
# Done! 130 cities saved.

# %% [markdown]
# ### Problem 3:
#
# Go to this url: https://www.flipkart.com/search?q=smartphones. This is the url to find phones in flipkart website. You have to extract the below things:
# 1. image url of the phone
# 2. name of the image
# 3. average ratings
# 4. total ratings
# 5. total reviews
# 6. discounted price
# 7. actual price
#
# Extract all the phones which are available in this website. So you have to use the pagination concept. **Also after requesting every page through the url, please wait for a while (minimum 2-3 seconds), otherwise your IP address can be banned to access the flipkart website later.**
#
# After collecting all the data, save that in a JSON file.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import json
import random

driver = webdriver.Chrome()
all_phones = []

for page in range(1, 4):
    print(f"\nPage {page}")
    driver.get(f"https://www.flipkart.com/search?q=smartphones&page={page}")
    time.sleep(5)
    
    # Using the working selector from debug
    products = driver.find_elements(By.CSS_SELECTOR, "div[data-id]")
    print(f"Found {len(products)} products")
    
    for p in products:
        try:
            img = p.find_element(By.TAG_NAME, "img")
            phone = {
                "image": img.get_attribute("src"),
                "name": img.get_attribute("alt"),
                "price": p.find_element(By.CSS_SELECTOR, "[class*='30jeq3']").text if p.find_elements(By.CSS_SELECTOR, "[class*='30jeq3']") else "N/A",
                "rating": p.find_element(By.CSS_SELECTOR, "[class*='LWZlK']").text if p.find_elements(By.CSS_SELECTOR, "[class*='LWZlK']") else "N/A"
            }
            all_phones.append(phone)
            print(f"  ✓ Added: {phone['name'][:50]}")
        except Exception as e:
            continue
    
    time.sleep(random.uniform(3, 4))

driver.quit()

with open("phones.json", "w", encoding="utf-8") as f:
    json.dump(all_phones, f, indent=2)

print(f"\n✅ Saved {len(all_phones)} phones to phones.json")
# Out:
# Page 1
# Found 24 products
#   ✓ Added: Ai+ Pulse 2 (Purple, 64 GB)
#   ✓ Added: vivo T5x 5G (Cyber Green, 128 GB)
#   ✓ Added: Samsung M06 5G (Sage Green, 128 GB)
#   ✓ Added: MOTOROLA Edge 60 Fusion 5G (PANTONE Slipstream, 12
#   ✓ Added: Samsung Galaxy F06 5G (Lit Violet, 128 GB)
#   ✓ Added: vivo T5x 5G (Star Silver, 128 GB)
#   ✓ Added: vivo T5x 5G (Cyber Green, 256 GB)
#   ✓ Added: POCO C85x Charger in the Box (Emerald Green, 64 GB
#   ✓ Added: realme P4x 5G (Matte Silver, 128 GB)
#   ✓ Added: Samsung Galaxy F06 5G (Bahama Blue, 128 GB)
#   ✓ Added: POCO C85 5G Charger in the Box (Power Black, 128 G
#   ✓ Added: realme P4 Lite 5G (Mosaic Green, 64 GB)
#   ✓ Added: POCO M7 Plus 5G (Aqua Blue, 128 GB)
#   ✓ Added: OnePlus Nord CE6 Lite (Hyper Black, 128 GB)
#   ✓ Added: POCO M7 Plus 5G (Carbon Black, 128 GB)
#   ✓ Added: realme P4 Lite (Sea Blue, 128 GB)
#   ✓ Added: Samsung Galaxy F36 5G (Violet, 128 GB)
#   ✓ Added: Samsung M06 5G (Sage Green, 128 GB)
#   ✓ Added: POCO C81x (Ice Blue, 64 GB)
#   ✓ Added: Ai+ Pulse 2 (Blue, 128 GB)
#   ✓ Added: POCO C71  - Locked with Airtel Prepaid (Desert Gol
#   ✓ Added: Ai+ Pulse 2 (Blue, 64 GB)
#   ✓ Added: Ai+ Pulse 2 (Purple, 128 GB)
#   ✓ Added: realme P4 Lite (Beach Gold, 128 GB)
#
# Page 2
# Found 24 products
#   ✓ Added: REDMI 15 5G (Sandy Purple, 128 GB)
#   ✓ Added: POCO C51 - Locked with Airtel Prepaid (Power Black
#   ✓ Added: MOTOROLA Edge 60 Fusion 5G (PANTONE Zephyr, 128 GB
#   ✓ Added: realme P4 Lite 5G (Mosaic Green, 128 GB)
#   ✓ Added: POCO M8 Charger in the Box (Frost Silver, 128 GB)
#   ✓ Added: Samsung Galaxy F36 5G (Black, 128 GB)
#   ✓ Added: OPPO K14x 5G (Icy Blue, 128 GB)
#   ✓ Added: POCO C81x (Crystal Black, 64 GB)
#   ✓ Added: realme P4x 5G (Elegant Pink, 128 GB)
#   ✓ Added: Ai+ Nova 2 Ultra 5G (Purple, 128 GB)
#   ✓ Added: POCO C85x Charger in the Box (Sunset Gold, 64 GB)
#   ✓ Added: realme P4x 5G (Matte Silver, 128 GB)
#   ✓ Added: vivo T4R 5G (Arctic White, 128 GB)
#   ✓ Added: realme P4 5G (Steel Grey, 256 GB)
#   ✓ Added: vivo T4 Pro 5G (Blaze Gold, 256 GB)
#   ✓ Added: MOTOROLA g37 (PANTONE Impenetrable, 64 GB)
#   ✓ Added: MOTOROLA G96 5G (Pantone Ashleigh Blue, 128 GB)
#   ✓ Added: MOTOROLA Edge 60 Fusion 5G (PANTONE Amazonite, 128
#   ✓ Added: OPPO K14x 5G (Icy Blue, 64 GB)
#   ✓ Added: POCO M7 Plus 5G (Carbon Black, 128 GB)
#   ✓ Added: Samsung Galaxy F06 5G (Lit Violet, 64 GB)
#   ✓ Added: POCO C85x Charger in the Box (Elite Black, 64 GB)
#   ✓ Added: MOTOROLA Edge 70 Fusion (Pantone SILHOUETTE, 256 G
#   ✓ Added: OnePlus Nord CE6 Lite (Vivid Mint, 128 GB)
#
# Page 3
# Found 24 products
#   ✓ Added: Samsung Galaxy F06 5G (Bahama Blue, 64 GB)
#   ✓ Added: MOTOROLA g35 5G (Leaf Green, 128 GB)
#   ✓ Added: realme P4x 5G (Lake Green, 128 GB)
#   ✓ Added: MOTOROLA Edge 60 Fusion 5G (PANTONE Mykonos Blue,
#   ✓ Added: realme P3 Lite 5G Charger in the Box (Midnight Lil
#   ✓ Added: OPPO K14 5G (Prism White, 128 GB)
#   ✓ Added: realme P4x 5G (Elegant Pink, 128 GB)
#   ✓ Added: vivo T4 Pro 5G (Nitro Blue, 256 GB)
#   ✓ Added: Samsung Galaxy F06 5G (Bahama Blue, 128 GB)
#   ✓ Added: Ai+ Pulse 1 (Purple, 64 GB)
#   ✓ Added: POCO C51 - Locked with Airtel Prepaid (Royal Blue,
#   ✓ Added: POCO M7 5G - Locked with Airtel Prepaid (Ocean Blu
#   ✓ Added: vivo T5x 5G (Cyber Green, 128 GB)
#   ✓ Added: Infinix GT 30 5G+ Pulse Green 128 (Pulse Green, 12
#   ✓ Added: Ai+ Pulse 1 (Green, 64 GB)
#   ✓ Added: MOTOROLA Edge 70 Fusion (Pantone BLUE SURF, 256 GB
#   ✓ Added: POCO C85 5G Charger in the Box (Power Black, 128 G
#   ✓ Added: OPPO Reno14 5G (Pearl White, 256 GB)
#   ✓ Added: MOTOROLA Edge 70 Fusion (Pantone SILHOUETTE, 256 G
#   ✓ Added: OnePlus Nord CE6 Lite (Hyper Black, 128 GB)
#   ✓ Added: OPPO K14 5G (Prism Violet, 256 GB)
#   ✓ Added: Apple iPhone 15 (Black, 128 GB)
#   ✓ Added: OPPO K13 5G with 7000mAh and 80W SUPERVOOC Charger
#   ✓ Added: Samsung Galaxy F06 5G (Lit Violet, 128 GB)
#
# ✅ Saved 72 phones to phones.json
